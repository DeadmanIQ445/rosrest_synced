# %%
import sys
sys.path.append("/home/shamil/Detectron2-Train-a-Instance-Segmentation-Model/")

# %%
from crop_image import clip_from_file
from crop_image import from_mask_to_coco

# %%
clip_from_file(
	clip_size=512,
	image_name='4326_pestrecy_16-33-24-(100-z)_cofp.tif',
	root='/home/shamil/new_data'
)
# Out:
# img_id: 4326_pestrecy_16-33-24-(100-z)_cofp
# create dir /home/shamil/new_data/size512/annotations
# clip mask successfully！(1/77)
# clip mask successfully！(2/77)
# clip mask successfully！(3/77)
# clip mask successfully！(4/77)
# clip mask successfully！(5/77)
# clip mask successfully！(6/77)
# clip mask successfully！(7/77)
# clip mask successfully！(8/77)
# clip mask successfully！(9/77)
# clip mask successfully！(10/77)
# clip mask successfully！(11/77)
# clip mask successfully！(12/77)
# clip mask successfully！(13/77)
# clip mask successfully！(14/77)
# clip mask successfully！(15/77)
# clip mask successfully！(16/77)
# clip mask successfully！(17/77)
# clip mask successfully！(18/77)
# clip mask successfully！(19/77)
# clip mask successfully！(20/77)
# clip mask successfully！(21/77)
# clip mask successfully！(22/77)
# clip mask successfully！(23/77)
# clip mask successfully！(24/77)
# clip mask successfully！(25/77)
# clip mask successfully！(26/77)
# clip mask successfully！(27/77)
# ...

# %%
from_mask_to_coco(
	image_path='/home/shamil/new_data/size512/uchastok_2021/11.tif',
	annotation_path='/home/shamil/new_data/size512/annotations/',
    json_output='/home/shamil/new_data/size512/annotations.json'
)
