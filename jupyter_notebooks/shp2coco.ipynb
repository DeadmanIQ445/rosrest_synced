# %% [markdown]
# ## Data imports

# %%
import os
import sys
sys.path.append('/home/shamil/Rosreest')

# %%
import datetime
import json
import re
import fnmatch
from utils.preprocess import pycococreatortools
from utils.preprocess.tif_process import *
from utils.preprocess.slice_dataset import slice
from pathlib import Path

# %% [markdown]
# Specify parameters of dataset

# %%
# root path for saving the tif and shp file.
ROOT = Path('/home/shamil/AILab/new_data')
img_path = 'Raster'
shp_path = 'Razmetka'

clip_size = 3800

# root path for saving the mask.
ROOT_DIR = ROOT / f'dataset'
IMAGE_DIR = ROOT_DIR /  "uchastok_2021"
ANNOTATION_DIR = ROOT_DIR / "annotations"

# %% [markdown]
# ## Configs (do not change)

# %%
INFO = {
    "description": "ZemleUchastki",
    "url": "",
    "version": "0.1.1",
    "year": 2021,
    "contributor": "Ibragim, Shamil",
    "date_created": datetime.datetime.utcnow().isoformat(' ')
}

LICENSES = [
    {
        "id": 1,
        "name": "",
        "url": ""
    }
]

CATEGORIES = [
    {
        'id': 1,
        'name': 'uchastok',
        'supercategory': 'land',
    },
]

# %% [markdown]
# ## Code (do not change)

# %%
def filter_for_jpeg(root, files):
    # file_types = ['*.jpeg', '*.jpg']
    file_types = ['*.tiff', '*.tif']
    file_types = r'|'.join([fnmatch.translate(x) for x in file_types])
    files = [os.path.join(root, f) for f in files]
    files = [f for f in files if re.match(file_types, f)]

    return files

def filter_for_annotations(root, files, image_filename):
    # file_types = ['*.png']
    file_types = ['*.tif']
    file_types = r'|'.join([fnmatch.translate(x) for x in file_types])
    basename_no_extension = os.path.splitext(os.path.basename(image_filename))[0]
    # file_name_prefix = basename_no_extension + '.*'
    files = [os.path.join(root, f) for f in files]
    files = [f for f in files if re.match(file_types, f)]
    # files = [f for f in files if re.match(file_name_prefix, os.path.splitext(os.path.basename(f))[0])]
    files = [f for f in files if basename_no_extension == os.path.splitext(os.path.basename(f))[0].split('_', 1)[0]]

    return files

def from_mask_to_coco(root, MARK, IMAGE, ANNOTATION):
    ROOT_DIR = root  / MARK
    IMAGE_DIR = ROOT_DIR /  IMAGE
    ANNOTATION_DIR = ROOT_DIR  / ANNOTATION
    if os.path.exists(ROOT_DIR):
        coco_output = {
            "info": INFO,
            "licenses": LICENSES,
            "categories": CATEGORIES,
            "images": [],
            "annotations": []
        }

        image_id = 1
        segmentation_id = 1

        # filter for jpeg images
        for root, _, files in os.walk(IMAGE_DIR):
            image_files = filter_for_jpeg(root, files)

            # go through each image
            for image_filename in image_files:
                image = Image.open(image_filename)
                image_info = pycococreatortools.create_image_info(
                    image_id, os.path.basename(image_filename), image.size)
                coco_output["images"].append(image_info)

                # filter for associated png annotations
                for root, _, files in os.walk(ANNOTATION_DIR):
                    annotation_files = filter_for_annotations(root, files, image_filename)

                    # go through each associated annotation
                    for annotation_filename in annotation_files:

                        print(annotation_filename)
                        class_id = [x['id'] for x in CATEGORIES if x['name'] in annotation_filename][0]

                        category_info = {'id': class_id, 'is_crowd': 'crowd' in image_filename}
                        binary_mask = np.asarray(Image.open(annotation_filename)
                                                 .convert('1')).astype(np.uint8)

                        annotation_info = pycococreatortools.create_annotation_info(
                            segmentation_id, image_id, category_info, binary_mask,
                            image.size, tolerance=2)

                        if annotation_info is not None:
                            coco_output["annotations"].append(annotation_info)

                        segmentation_id = segmentation_id + 1

                image_id = image_id + 1

        with open('{}/uchastok_{}2021.json'.format(ROOT_DIR, MARK), 'w') as output_json_file:
            json.dump(coco_output, output_json_file)
    else:
        print(ROOT_DIR + ' does not exit!')

# %% [markdown]
# ## Launching code

# %%
def main():
    clip_from_file(clip_size, str(ROOT), img_path, shp_path)
    slice(str(ROOT_DIR), train=0.6, eval=0.2, test=0.2)
    from_mask_to_coco(ROOT_DIR, 'train', "uchastok_2021", "annotations")
    from_mask_to_coco(ROOT_DIR, 'eval', "uchastok_2021", "annotations")
    from_mask_to_coco(ROOT_DIR, 'test', "uchastok_2021", "annotations")

if __name__ == "__main__":
    main()
# Out:
# clip mask successfully！(1/1)
# clip mask successfully！(2/1)
# clip mask successfully！(3/1)
# clip mask successfully！(4/1)
# clip mask successfully！(5/1)
# clip mask successfully！(6/1)
# clip mask successfully！(7/1)
# clip mask successfully！(8/1)
# clip mask successfully！(9/1)
# clip mask successfully！(10/1)
# clip mask successfully！(11/1)
# clip mask successfully！(12/1)
# clip mask successfully！(13/1)
# clip mask successfully！(14/1)
# clip mask successfully！(15/1)
# clip mask successfully！(16/1)
# clip mask successfully！(17/1)
# clip mask successfully！(18/1)
# clip mask successfully！(19/1)
# clip mask successfully！(20/1)
# clip mask successfully！(21/1)
# clip mask successfully！(22/1)
# clip mask successfully！(23/1)
# clip mask successfully！(24/1)
# clip mask successfully！(25/1)
# clip mask successfully！(26/1)
# clip mask successfully！(27/1)
# clip mask successfully！(28/1)
# clip mask successfully！(29/1)
# clip mask successfully！(30/1)
# clip mask successfully！(31/1)
# clip mask successfully！(32/1)
# clip mask successfully！(33/1)
# clip mask successfully！(34/1)
# clip mask successfully！(35/1)
# clip mask successfully！(36/1)
# clip mask successfully！(37/1)
# clip mask successfully！(38/1)
# clip mask successfully！(39/1)
# clip mask successfully！(40/1)
# clip mask successfully！(41/1)
# clip mask successfully！(42/1)
# clip mask successfully！(43/1)
# clip mask successfully！(44/1)
# clip mask successfully！(45/1)
# clip mask successfully！(46/1)
# clip mask successfully！(47/1)
# clip mask successfully！(48/1)
# clip mask successfully！(49/1)
# clip mask successfully！(50/1)
# clip mask successfully！(51/1)
# clip mask successfully！(52/1)
# clip mask successfully！(53/1)
# clip mask successfully！(54/1)
# clip mask successfully！(55/1)
# clip mask successfully！(56/1)
# clip mask successfully！(57/1)
# clip mask successfully！(58/1)
# clip mask successfully！(59/1)
# clip mask successfully！(60/1)
# clip mask successfully！(61/1)
# clip mask successfully！(62/1)
# clip mask successfully！(63/1)
# clip mask successfully！(64/1)
# clip mask successfully！(65/1)
# clip mask successfully！(66/1)
# clip mask successfully！(67/1)
# clip mask successfully！(68/1)
# clip mask successfully！(69/1)
# clip mask successfully！(70/1)
# clip mask successfully！(71/1)
# clip mask successfully！(72/1)
# clip mask successfully！(73/1)
# clip mask successfully！(74/1)
# clip mask successfully！(75/1)
# clip mask successfully！(76/1)
# clip mask successfully！(77/1)
# clip mask successfully！(78/1)
# clip mask successfully！(79/1)
# clip mask successfully！(80/1)
# clip mask successfully！(81/1)
# clip mask successfully！(82/1)
# clip mask successfully！(83/1)
# clip mask successfully！(84/1)
# clip mask successfully！(85/1)
# clip successfully！(1/1)
# clip mask successfully！(1/1)
# clip mask successfully！(2/1)
# clip mask successfully！(3/1)
# clip mask successfully！(4/1)
# clip mask successfully！(5/1)
# clip mask successfully！(6/1)
# clip mask successfully！(7/1)
# clip mask successfully！(8/1)
# clip mask successfully！(9/1)
# clip mask successfully！(10/1)
# clip mask successfully！(11/1)
# clip mask successfully！(12/1)
# clip mask successfully！(13/1)
# clip mask successfully！(14/1)
# clip mask successfully！(15/1)
# clip mask successfully！(16/1)
# clip mask successfully！(17/1)
# clip mask successfully！(18/1)
# clip mask successfully！(19/1)
# clip mask successfully！(20/1)
# clip mask successfully！(21/1)
# clip mask successfully！(22/1)
# clip mask successfully！(23/1)
# clip mask successfully！(24/1)
# clip mask successfully！(25/1)
# clip mask successfully！(26/1)
# clip mask successfully！(27/1)
# clip mask successfully！(28/1)
# clip mask successfully！(29/1)
# clip mask successfully！(30/1)
# clip mask successfully！(31/1)
# clip mask successfully！(32/1)
# clip mask successfully！(33/1)
# clip mask successfully！(34/1)
# clip mask successfully！(35/1)
# clip mask successfully！(36/1)
# clip mask successfully！(37/1)
# clip mask successfully！(38/1)
# clip mask successfully！(39/1)
# clip mask successfully！(40/1)
# clip mask successfully！(41/1)
# clip mask successfully！(42/1)
# clip mask successfully！(43/1)
# clip mask successfully！(44/1)
# clip mask successfully！(45/1)
# clip mask successfully！(46/1)
# clip mask successfully！(47/1)
# clip mask successfully！(48/1)
# clip mask successfully！(49/1)
# clip mask successfully！(50/1)
# clip mask successfully！(51/1)
# clip mask successfully！(52/1)
# clip mask successfully！(53/1)
# clip mask successfully！(54/1)
# clip mask successfully！(55/1)
# clip mask successfully！(56/1)
# clip mask successfully！(57/1)
# clip mask successfully！(58/1)
# clip mask successfully！(59/1)
# clip mask successfully！(60/1)
# clip mask successfully！(61/1)
# clip mask successfully！(62/1)
# clip mask successfully！(63/1)
# clip mask successfully！(64/1)
# clip mask successfully！(65/1)
# clip mask successfully！(66/1)
# clip mask successfully！(67/1)
# clip mask successfully！(68/1)
# clip mask successfully！(69/1)
# clip mask successfully！(70/1)
# clip mask successfully！(71/1)
# clip mask successfully！(72/1)
# clip mask successfully！(73/1)
# clip mask successfully！(74/1)
# clip mask successfully！(75/1)
# clip mask successfully！(76/1)
# clip mask successfully！(77/1)
# clip mask successfully！(78/1)
# clip mask successfully！(79/1)
# clip mask successfully！(80/1)
# clip mask successfully！(81/1)
# clip mask successfully！(82/1)
# clip mask successfully！(83/1)
# clip mask successfully！(84/1)
# clip mask successfully！(85/1)
# clip mask successfully！(86/1)
# clip mask successfully！(87/1)
# clip mask successfully！(88/1)
# clip mask successfully！(89/1)
# clip mask successfully！(90/1)
# clip mask successfully！(91/1)
# clip mask successfully！(92/1)
# clip mask successfully！(93/1)
# clip mask successfully！(94/1)
# clip mask successfully！(95/1)
# clip mask successfully！(96/1)
# clip mask successfully！(97/1)
# clip mask successfully！(98/1)
# clip mask successfully！(99/1)
# clip mask successfully！(100/1)
# clip mask successfully！(101/1)
# clip successfully！(1/1)
# clip mask successfully！(1/1)
# clip mask successfully！(2/1)
# clip mask successfully！(3/1)
# clip mask successfully！(4/1)
# clip mask successfully！(5/1)
# clip mask successfully！(6/1)
# clip mask successfully！(7/1)
# clip mask successfully！(8/1)
# clip mask successfully！(9/1)
# clip mask successfully！(10/1)
# clip mask successfully！(11/1)
# clip mask successfully！(12/1)
# clip mask successfully！(13/1)
# clip mask successfully！(14/1)
# clip mask successfully！(15/1)
# clip mask successfully！(16/1)
# clip mask successfully！(17/1)
# clip mask successfully！(18/1)
# clip mask successfully！(19/1)
# clip mask successfully！(20/1)
# clip mask successfully！(21/1)
# clip mask successfully！(22/1)
# clip mask successfully！(23/1)
# clip mask successfully！(24/1)
# clip mask successfully！(25/1)
# clip mask successfully！(26/1)
# clip mask successfully！(27/1)
# clip mask successfully！(28/1)
# clip mask successfully！(29/1)
# clip mask successfully！(30/1)
# clip mask successfully！(31/1)
# clip mask successfully！(32/1)
# clip mask successfully！(33/1)
# clip mask successfully！(34/1)
# clip mask successfully！(35/1)
# clip mask successfully！(36/1)
# clip mask successfully！(37/1)
# clip mask successfully！(38/1)
# clip mask successfully！(39/1)
# clip mask successfully！(40/1)
# clip mask successfully！(41/1)
# clip mask successfully！(42/1)
# clip mask successfully！(43/1)
# clip mask successfully！(44/1)
# clip mask successfully！(45/1)
# clip mask successfully！(46/1)
# clip mask successfully！(47/1)
# clip mask successfully！(48/1)
# clip mask successfully！(49/1)
# clip mask successfully！(50/1)
# clip mask successfully！(51/1)
# clip mask successfully！(52/1)
# clip mask successfully！(53/1)
# clip mask successfully！(54/1)
# clip mask successfully！(55/1)
# clip mask successfully！(56/1)
# clip mask successfully！(57/1)
# clip mask successfully！(58/1)
# clip mask successfully！(59/1)
# clip mask successfully！(60/1)
# clip mask successfully！(61/1)
# clip mask successfully！(62/1)
# clip mask successfully！(63/1)
# clip mask successfully！(64/1)
# clip mask successfully！(65/1)
# clip mask successfully！(66/1)
# clip mask successfully！(67/1)
# clip mask successfully！(68/1)
# clip mask successfully！(69/1)
# clip mask successfully！(70/1)
# clip mask successfully！(71/1)
# clip mask successfully！(72/1)
# clip successfully！(1/1)
# clip mask successfully！(1/1)
# clip mask successfully！(2/1)
# clip mask successfully！(3/1)
# clip mask successfully！(4/1)
# clip mask successfully！(5/1)
# clip mask successfully！(6/1)
# clip mask successfully！(7/1)
# clip mask successfully！(8/1)
# clip mask successfully！(9/1)
# clip mask successfully！(10/1)
# clip mask successfully！(11/1)
# clip mask successfully！(12/1)
# clip mask successfully！(13/1)
# clip mask successfully！(14/1)
# clip mask successfully！(15/1)
# clip mask successfully！(16/1)
# clip mask successfully！(17/1)
# clip mask successfully！(18/1)
# clip mask successfully！(19/1)
# clip mask successfully！(20/1)
# clip mask successfully！(21/1)
# clip successfully！(1/1)
# clip mask successfully！(1/1)
# clip mask successfully！(2/1)
# clip mask successfully！(3/1)
# clip mask successfully！(4/1)
# clip mask successfully！(5/1)
# clip mask successfully！(6/1)
# clip mask successfully！(7/1)
# clip mask successfully！(8/1)
# clip mask successfully！(9/1)
# clip mask successfully！(10/1)
# clip mask successfully！(11/1)
# clip mask successfully！(12/1)
# clip mask successfully！(13/1)
# clip mask successfully！(14/1)
# clip mask successfully！(15/1)
# clip mask successfully！(16/1)
# clip mask successfully！(17/1)
# clip mask successfully！(18/1)
# clip mask successfully！(19/1)
# clip mask successfully！(20/1)
# clip mask successfully！(21/1)
# clip mask successfully！(22/1)
# clip mask successfully！(23/1)
# clip mask successfully！(24/1)
# clip mask successfully！(25/1)
# clip mask successfully！(26/1)
# clip mask successfully！(27/1)
# clip mask successfully！(28/1)
# clip mask successfully！(29/1)
# clip mask successfully！(30/1)
# clip mask successfully！(31/1)
# clip mask successfully！(32/1)
# clip mask successfully！(33/1)
# clip mask successfully！(34/1)
# clip mask successfully！(35/1)
# clip mask successfully！(36/1)
# clip mask successfully！(37/1)
# clip mask successfully！(38/1)
# clip mask successfully！(39/1)
# clip mask successfully！(40/1)
# clip mask successfully！(41/1)
# clip mask successfully！(42/1)
# clip mask successfully！(43/1)
# clip mask successfully！(44/1)
# clip mask successfully！(45/1)
# clip mask successfully！(46/1)
# clip mask successfully！(47/1)
# clip mask successfully！(48/1)
# clip mask successfully！(49/1)
# clip mask successfully！(50/1)
# clip mask successfully！(51/1)
# clip mask successfully！(52/1)
# clip mask successfully！(53/1)
# clip mask successfully！(54/1)
# clip mask successfully！(55/1)
# clip mask successfully！(56/1)
# clip mask successfully！(57/1)
# clip mask successfully！(58/1)
# clip mask successfully！(59/1)
# clip mask successfully！(60/1)
# clip mask successfully！(61/1)
# clip mask successfully！(62/1)
# clip mask successfully！(63/1)
# clip mask successfully！(64/1)
# clip mask successfully！(65/1)
# clip mask successfully！(66/1)
# clip mask successfully！(67/1)
# clip mask successfully！(68/1)
# clip mask successfully！(69/1)
# clip mask successfully！(70/1)
# clip mask successfully！(71/1)
# clip mask successfully！(72/1)
# clip mask successfully！(73/1)
# clip mask successfully！(74/1)
# clip mask successfully！(75/1)
# clip mask successfully！(76/1)
# clip mask successfully！(77/1)
# clip mask successfully！(78/1)
# clip mask successfully！(79/1)
# clip mask successfully！(80/1)
# clip mask successfully！(81/1)
# clip mask successfully！(82/1)
# clip mask successfully！(83/1)
# clip mask successfully！(84/1)
# clip mask successfully！(85/1)
# clip mask successfully！(86/1)
# clip mask successfully！(87/1)
# clip mask successfully！(88/1)
# clip mask successfully！(89/1)
# clip mask successfully！(90/1)
# clip mask successfully！(91/1)
# clip mask successfully！(92/1)
# clip mask successfully！(93/1)
# clip mask successfully！(94/1)
# clip mask successfully！(95/1)
# clip mask successfully！(96/1)
# clip mask successfully！(97/1)
# clip mask successfully！(98/1)
# clip mask successfully！(99/1)
# clip mask successfully！(100/1)
# clip mask successfully！(101/1)
# clip mask successfully！(102/1)
# clip mask successfully！(103/1)
# clip mask successfully！(104/1)
# clip mask successfully！(105/1)
# clip mask successfully！(106/1)
# clip mask successfully！(107/1)
# clip mask successfully！(108/1)
# clip mask successfully！(109/1)
# clip mask successfully！(110/1)
# clip mask successfully！(111/1)
# clip mask successfully！(112/1)
# clip mask successfully！(113/1)
# clip mask successfully！(114/1)
# clip mask successfully！(115/1)
# clip mask successfully！(116/1)
# clip mask successfully！(117/1)
# clip mask successfully！(118/1)
# clip mask successfully！(119/1)
# clip mask successfully！(120/1)
# clip mask successfully！(121/1)
# clip mask successfully！(122/1)
# clip mask successfully！(123/1)
# clip mask successfully！(124/1)
# clip mask successfully！(125/1)
# clip mask successfully！(126/1)
# clip mask successfully！(127/1)
# clip mask successfully！(128/1)
# clip mask successfully！(129/1)
# clip mask successfully！(130/1)
# clip mask successfully！(131/1)
# clip mask successfully！(132/1)
# clip mask successfully！(133/1)
# clip mask successfully！(134/1)
# clip mask successfully！(135/1)
# clip mask successfully！(136/1)
# clip mask successfully！(137/1)
# clip mask successfully！(138/1)
# clip mask successfully！(139/1)
# clip mask successfully！(140/1)
# clip mask successfully！(141/1)
# clip mask successfully！(142/1)
# clip mask successfully！(143/1)
# clip mask successfully！(144/1)
# clip mask successfully！(145/1)
# clip successfully！(1/1)
# clip mask successfully！(1/1)
# clip mask successfully！(2/1)
# clip mask successfully！(3/1)
# clip mask successfully！(4/1)
# clip mask successfully！(5/1)
# clip mask successfully！(6/1)
# clip mask successfully！(7/1)
# clip mask successfully！(8/1)
# clip mask successfully！(9/1)
# clip mask successfully！(10/1)
# clip mask successfully！(11/1)
# clip mask successfully！(12/1)
# clip mask successfully！(13/1)
# clip mask successfully！(14/1)
# clip mask successfully！(15/1)
# clip mask successfully！(16/1)
# clip mask successfully！(17/1)
# clip mask successfully！(18/1)
# clip mask successfully！(19/1)
# clip mask successfully！(20/1)
# clip mask successfully！(21/1)
# clip mask successfully！(22/1)
# clip mask successfully！(23/1)
# clip mask successfully！(24/1)
# clip mask successfully！(25/1)
# clip mask successfully！(26/1)
# clip mask successfully！(27/1)
# clip mask successfully！(28/1)
# clip mask successfully！(29/1)
# clip mask successfully！(30/1)
# clip mask successfully！(31/1)
# clip mask successfully！(32/1)
# clip mask successfully！(33/1)
# clip mask successfully！(34/1)
# clip mask successfully！(35/1)
# clip successfully！(1/1)
# clip mask successfully！(1/1)
# clip mask successfully！(2/1)
# clip mask successfully！(3/1)
# clip mask successfully！(4/1)
# clip mask successfully！(5/1)
# clip mask successfully！(6/1)
# clip mask successfully！(7/1)
# clip mask successfully！(8/1)
# clip mask successfully！(9/1)
# clip mask successfully！(10/1)
# clip mask successfully！(11/1)
# clip mask successfully！(12/1)
# clip mask successfully！(13/1)
# clip mask successfully！(14/1)
# clip mask successfully！(15/1)
# clip mask successfully！(16/1)
# clip mask successfully！(17/1)
# clip mask successfully！(18/1)
# clip successfully！(1/1)
# clip mask successfully！(1/1)
# clip mask successfully！(2/1)
# clip mask successfully！(3/1)
# clip mask successfully！(4/1)
# clip mask successfully！(5/1)
# clip mask successfully！(6/1)
# clip mask successfully！(7/1)
# clip mask successfully！(8/1)
# clip mask successfully！(9/1)
# clip mask successfully！(10/1)
# clip mask successfully！(11/1)
# clip mask successfully！(12/1)
# clip mask successfully！(13/1)
# clip mask successfully！(14/1)
# clip mask successfully！(15/1)
# clip mask successfully！(16/1)
# clip mask successfully！(17/1)
# clip mask successfully！(18/1)
# clip mask successfully！(19/1)
# clip mask successfully！(20/1)
# clip mask successfully！(21/1)
# clip mask successfully！(22/1)
# clip mask successfully！(23/1)
# clip mask successfully！(24/1)
# clip mask successfully！(25/1)
# clip mask successfully！(26/1)
# clip mask successfully！(27/1)
# clip mask successfully！(28/1)
# clip mask successfully！(29/1)
# clip mask successfully！(30/1)
# clip mask successfully！(31/1)
# clip mask successfully！(32/1)
# clip mask successfully！(33/1)
# clip mask successfully！(34/1)
# clip mask successfully！(35/1)
# clip mask successfully！(36/1)
# clip mask successfully！(37/1)
# clip mask successfully！(38/1)
# clip mask successfully！(39/1)
# clip mask successfully！(40/1)
# clip mask successfully！(41/1)
# clip mask successfully！(42/1)
# clip mask successfully！(43/1)
# clip mask successfully！(44/1)
# clip mask successfully！(45/1)
# clip mask successfully！(46/1)
# clip mask successfully！(47/1)
# clip mask successfully！(48/1)
# clip mask successfully！(49/1)
# clip mask successfully！(50/1)
# clip mask successfully！(51/1)
# clip mask successfully！(52/1)
# clip mask successfully！(53/1)
# clip mask successfully！(54/1)
# clip mask successfully！(55/1)
# clip mask successfully！(56/1)
# clip mask successfully！(57/1)
# clip mask successfully！(58/1)
# clip mask successfully！(59/1)
# clip mask successfully！(60/1)
# clip mask successfully！(61/1)
# clip mask successfully！(62/1)
# clip mask successfully！(63/1)
# clip mask successfully！(64/1)
# clip mask successfully！(65/1)
# clip mask successfully！(66/1)
# clip mask successfully！(67/1)
# clip mask successfully！(68/1)
# clip mask successfully！(69/1)
# clip mask successfully！(70/1)
# clip mask successfully！(71/1)
# clip mask successfully！(72/1)
# clip mask successfully！(73/1)
# clip mask successfully！(74/1)
# clip mask successfully！(75/1)
# clip mask successfully！(76/1)
# clip mask successfully！(77/1)
# clip mask successfully！(78/1)
# clip mask successfully！(79/1)
# clip mask successfully！(80/1)
# clip mask successfully！(81/1)
# clip mask successfully！(82/1)
# clip mask successfully！(83/1)
# clip mask successfully！(84/1)
# clip mask successfully！(85/1)
# clip mask successfully！(86/1)
# clip mask successfully！(87/1)
# clip mask successfully！(88/1)
# clip mask successfully！(89/1)
# clip mask successfully！(90/1)
# clip mask successfully！(91/1)
# clip mask successfully！(92/1)
# clip mask successfully！(93/1)
# clip mask successfully！(94/1)
# clip mask successfully！(95/1)
# clip mask successfully！(96/1)
# clip mask successfully！(97/1)
# clip mask successfully！(98/1)
# clip mask successfully！(99/1)
# clip mask successfully！(100/1)
# clip mask successfully！(101/1)
# clip mask successfully！(102/1)
# clip mask successfully！(103/1)
# clip mask successfully！(104/1)
# clip mask successfully！(105/1)
# clip mask successfully！(106/1)
# clip mask successfully！(107/1)
# clip mask successfully！(108/1)
# clip mask successfully！(109/1)
# clip mask successfully！(110/1)
# clip mask successfully！(111/1)
# clip mask successfully！(112/1)
# clip mask successfully！(113/1)
# clip mask successfully！(114/1)
# clip mask successfully！(115/1)
# clip mask successfully！(116/1)
# clip mask successfully！(117/1)
# clip mask successfully！(118/1)
# clip mask successfully！(119/1)
# clip mask successfully！(120/1)
# clip mask successfully！(121/1)
# clip mask successfully！(122/1)
# clip mask successfully！(123/1)
# clip mask successfully！(124/1)
# clip mask successfully！(125/1)
# clip mask successfully！(126/1)
# clip mask successfully！(127/1)
# clip mask successfully！(128/1)
# clip mask successfully！(129/1)
# clip mask successfully！(130/1)
# clip mask successfully！(131/1)
# clip mask successfully！(132/1)
# clip mask successfully！(133/1)
# clip mask successfully！(134/1)
# clip mask successfully！(135/1)
# clip mask successfully！(136/1)
# clip mask successfully！(137/1)
# clip mask successfully！(138/1)
# clip successfully！(1/1)
# clip mask successfully！(1/1)
# clip mask successfully！(2/1)
# clip mask successfully！(3/1)
# clip mask successfully！(4/1)
# clip mask successfully！(5/1)
# clip mask successfully！(6/1)
# clip mask successfully！(7/1)
# clip mask successfully！(8/1)
# clip mask successfully！(9/1)
# clip mask successfully！(10/1)
# clip mask successfully！(11/1)
# clip mask successfully！(12/1)
# clip mask successfully！(13/1)
# clip mask successfully！(14/1)
# clip mask successfully！(15/1)
# clip mask successfully！(16/1)
# clip mask successfully！(17/1)
# clip mask successfully！(18/1)
# clip mask successfully！(19/1)
# clip mask successfully！(20/1)
# clip mask successfully！(21/1)
# clip mask successfully！(22/1)
# clip mask successfully！(23/1)
# clip mask successfully！(24/1)
# clip mask successfully！(25/1)
# clip mask successfully！(26/1)
# clip mask successfully！(27/1)
# clip mask successfully！(28/1)
# clip mask successfully！(29/1)
# clip mask successfully！(30/1)
# clip mask successfully！(31/1)
# clip mask successfully！(32/1)
# clip mask successfully！(33/1)
# clip mask successfully！(34/1)
# clip mask successfully！(35/1)
# clip mask successfully！(36/1)
# clip mask successfully！(37/1)
# clip mask successfully！(38/1)
# clip mask successfully！(39/1)
# clip mask successfully！(40/1)
# clip mask successfully！(41/1)
# clip mask successfully！(42/1)
# clip mask successfully！(43/1)
# clip mask successfully！(44/1)
# clip mask successfully！(45/1)
# clip mask successfully！(46/1)
# clip mask successfully！(47/1)
# clip mask successfully！(48/1)
# clip mask successfully！(49/1)
# clip mask successfully！(50/1)
# clip mask successfully！(51/1)
# clip mask successfully！(52/1)
# clip mask successfully！(53/1)
# clip mask successfully！(54/1)
# clip mask successfully！(55/1)
# clip mask successfully！(56/1)
# clip mask successfully！(57/1)
# clip mask successfully！(58/1)
# clip mask successfully！(59/1)
# clip mask successfully！(60/1)
# clip mask successfully！(61/1)
# clip mask successfully！(62/1)
# clip mask successfully！(63/1)
# clip mask successfully！(64/1)
# clip mask successfully！(65/1)
# clip mask successfully！(66/1)
# clip mask successfully！(67/1)
# clip mask successfully！(68/1)
# clip mask successfully！(69/1)
# clip mask successfully！(70/1)
# clip mask successfully！(71/1)
# clip mask successfully！(72/1)
# clip mask successfully！(73/1)
# clip mask successfully！(74/1)
# clip mask successfully！(75/1)
# clip mask successfully！(76/1)
# clip mask successfully！(77/1)
# clip mask successfully！(78/1)
# clip mask successfully！(79/1)
# clip mask successfully！(80/1)
# clip mask successfully！(81/1)
# clip mask successfully！(82/1)
# clip mask successfully！(83/1)
# clip mask successfully！(84/1)
# clip mask successfully！(85/1)
# clip mask successfully！(86/1)
# clip mask successfully！(87/1)
# clip mask successfully！(88/1)
# clip mask successfully！(89/1)
# clip mask successfully！(90/1)
# clip mask successfully！(91/1)
# clip mask successfully！(92/1)
# clip mask successfully！(93/1)
# clip mask successfully！(94/1)
# clip mask successfully！(95/1)
# clip mask successfully！(96/1)
# clip mask successfully！(97/1)
# clip mask successfully！(98/1)
# clip mask successfully！(99/1)
# clip mask successfully！(100/1)
# clip mask successfully！(101/1)
# clip mask successfully！(102/1)
# clip mask successfully！(103/1)
# clip mask successfully！(104/1)
# clip mask successfully！(105/1)
# clip mask successfully！(106/1)
# clip mask successfully！(107/1)
# clip mask successfully！(108/1)
# clip mask successfully！(109/1)
# clip mask successfully！(110/1)
# clip successfully！(1/1)
# clip mask successfully！(1/1)
# clip mask successfully！(2/1)
# clip mask successfully！(3/1)
# clip mask successfully！(4/1)
# clip mask successfully！(5/1)
# clip mask successfully！(6/1)
# clip mask successfully！(7/1)
# clip mask successfully！(8/1)
# clip mask successfully！(9/1)
# clip mask successfully！(10/1)
# clip mask successfully！(11/1)
# clip mask successfully！(12/1)
# clip mask successfully！(13/1)
# clip mask successfully！(14/1)
# clip mask successfully！(15/1)
# clip mask successfully！(16/1)
# clip mask successfully！(17/1)
# clip mask successfully！(18/1)
# clip mask successfully！(19/1)
# clip mask successfully！(20/1)
# clip mask successfully！(21/1)
# clip mask successfully！(22/1)
# clip mask successfully！(23/1)
# clip mask successfully！(24/1)
# clip mask successfully！(25/1)
# clip mask successfully！(26/1)
# clip mask successfully！(27/1)
# clip mask successfully！(28/1)
# clip mask successfully！(29/1)
# clip mask successfully！(30/1)
# clip mask successfully！(31/1)
# clip mask successfully！(32/1)
# clip mask successfully！(33/1)
# clip mask successfully！(34/1)
# clip mask successfully！(35/1)
# clip mask successfully！(36/1)
# clip mask successfully！(37/1)
# clip mask successfully！(38/1)
# clip mask successfully！(39/1)
# clip mask successfully！(40/1)
# clip mask successfully！(41/1)
# clip mask successfully！(42/1)
# clip mask successfully！(43/1)
# clip mask successfully！(44/1)
# clip mask successfully！(45/1)
# clip mask successfully！(46/1)
# clip mask successfully！(47/1)
# clip mask successfully！(48/1)
# clip mask successfully！(49/1)
# clip mask successfully！(50/1)
# clip mask successfully！(51/1)
# clip mask successfully！(52/1)
# clip mask successfully！(53/1)
# clip mask successfully！(54/1)
# clip mask successfully！(55/1)
# clip mask successfully！(56/1)
# clip mask successfully！(57/1)
# clip mask successfully！(58/1)
# clip mask successfully！(59/1)
# clip mask successfully！(60/1)
# clip mask successfully！(61/1)
# clip mask successfully！(62/1)
# clip mask successfully！(63/1)
# clip mask successfully！(64/1)
# clip mask successfully！(65/1)
# clip mask successfully！(66/1)
# clip mask successfully！(67/1)
# clip mask successfully！(68/1)
# clip mask successfully！(69/1)
# clip mask successfully！(70/1)
# clip mask successfully！(71/1)
# clip mask successfully！(72/1)
# clip mask successfully！(73/1)
# clip mask successfully！(74/1)
# clip mask successfully！(75/1)
# clip mask successfully！(76/1)
# clip mask successfully！(77/1)
# clip mask successfully！(78/1)
# clip mask successfully！(79/1)
# clip mask successfully！(80/1)
# clip mask successfully！(81/1)
# clip mask successfully！(82/1)
# clip mask successfully！(83/1)
# clip mask successfully！(84/1)
# clip mask successfully！(85/1)
# clip mask successfully！(86/1)
# clip mask successfully！(87/1)
# clip mask successfully！(88/1)
# clip mask successfully！(89/1)
# clip mask successfully！(90/1)
# clip successfully！(1/1)
# clip mask successfully！(1/1)
# clip mask successfully！(2/1)
# clip mask successfully！(3/1)
# clip mask successfully！(4/1)
# clip mask successfully！(5/1)
# clip mask successfully！(6/1)
# clip mask successfully！(7/1)
# clip mask successfully！(8/1)
# clip mask successfully！(9/1)
# clip mask successfully！(10/1)
# clip mask successfully！(11/1)
# clip mask successfully！(12/1)
# clip mask successfully！(13/1)
# clip mask successfully！(14/1)
# clip mask successfully！(15/1)
# clip mask successfully！(16/1)
# clip mask successfully！(17/1)
# clip mask successfully！(18/1)
# clip mask successfully！(19/1)
# clip mask successfully！(20/1)
# clip mask successfully！(21/1)
# clip mask successfully！(22/1)
# clip mask successfully！(23/1)
# clip mask successfully！(24/1)
# clip mask successfully！(25/1)
# clip mask successfully！(26/1)
# clip mask successfully！(27/1)
# clip mask successfully！(28/1)
# clip mask successfully！(29/1)
# clip mask successfully！(30/1)
# clip mask successfully！(31/1)
# clip mask successfully！(32/1)
# clip mask successfully！(33/1)
# clip mask successfully！(34/1)
# clip mask successfully！(35/1)
# clip mask successfully！(36/1)
# clip mask successfully！(37/1)
# clip mask successfully！(38/1)
# clip mask successfully！(39/1)
# clip mask successfully！(40/1)
# clip mask successfully！(41/1)
# clip mask successfully！(42/1)
# clip mask successfully！(43/1)
# clip mask successfully！(44/1)
# clip mask successfully！(45/1)
# clip mask successfully！(46/1)
# clip mask successfully！(47/1)
# clip mask successfully！(48/1)
# clip mask successfully！(49/1)
# clip mask successfully！(50/1)
# clip successfully！(1/1)
# clip mask successfully！(1/1)
# clip mask successfully！(2/1)
# clip mask successfully！(3/1)
# clip mask successfully！(4/1)
# clip mask successfully！(5/1)
# clip mask successfully！(6/1)
# clip mask successfully！(7/1)
# clip mask successfully！(8/1)
# clip mask successfully！(9/1)
# clip mask successfully！(10/1)
# clip mask successfully！(11/1)
# clip mask successfully！(12/1)
# clip mask successfully！(13/1)
# clip mask successfully！(14/1)
# clip mask successfully！(15/1)
# clip mask successfully！(16/1)
# clip mask successfully！(17/1)
# clip mask successfully！(18/1)
# clip mask successfully！(19/1)
# clip mask successfully！(20/1)
# clip mask successfully！(21/1)
# clip mask successfully！(22/1)
# clip mask successfully！(23/1)
# clip mask successfully！(24/1)
# clip mask successfully！(25/1)
# clip mask successfully！(26/1)
# clip mask successfully！(27/1)
# clip mask successfully！(28/1)
# clip mask successfully！(29/1)
# clip mask successfully！(30/1)
# clip mask successfully！(31/1)
# clip mask successfully！(32/1)
# clip mask successfully！(33/1)
# clip mask successfully！(34/1)
# clip mask successfully！(35/1)
# clip mask successfully！(36/1)
# clip mask successfully！(37/1)
# clip mask successfully！(38/1)
# clip mask successfully！(39/1)
# clip mask successfully！(40/1)
# clip mask successfully！(41/1)
# clip mask successfully！(42/1)
# clip mask successfully！(43/1)
# clip mask successfully！(44/1)
# clip mask successfully！(45/1)
# clip mask successfully！(46/1)
# clip mask successfully！(47/1)
# clip mask successfully！(48/1)
# clip mask successfully！(49/1)
# clip mask successfully！(50/1)
# clip mask successfully！(51/1)
# clip mask successfully！(52/1)
# clip mask successfully！(53/1)
# clip mask successfully！(54/1)
# clip mask successfully！(55/1)
# clip mask successfully！(56/1)
# clip mask successfully！(57/1)
# clip mask successfully！(58/1)
# clip mask successfully！(59/1)
# clip mask successfully！(60/1)
# clip mask successfully！(61/1)
# clip mask successfully！(62/1)
# clip mask successfully！(63/1)
# clip mask successfully！(64/1)
# clip mask successfully！(65/1)
# clip mask successfully！(66/1)
# clip mask successfully！(67/1)
# clip mask successfully！(68/1)
# clip mask successfully！(69/1)
# clip mask successfully！(70/1)
# clip mask successfully！(71/1)
# clip mask successfully！(72/1)
# clip mask successfully！(73/1)
# clip mask successfully！(74/1)
# clip mask successfully！(75/1)
# clip mask successfully！(76/1)
# clip mask successfully！(77/1)
# clip mask successfully！(78/1)
# clip mask successfully！(79/1)
# clip mask successfully！(80/1)
# clip mask successfully！(81/1)
# clip mask successfully！(82/1)
# clip mask successfully！(83/1)
# clip mask successfully！(84/1)
# clip mask successfully！(85/1)
# clip mask successfully！(86/1)
# clip mask successfully！(87/1)
# clip mask successfully！(88/1)
# clip mask successfully！(89/1)
# clip mask successfully！(90/1)
# clip mask successfully！(91/1)
# clip mask successfully！(92/1)
# clip mask successfully！(93/1)
# clip mask successfully！(94/1)
# clip mask successfully！(95/1)
# clip mask successfully！(96/1)
# clip mask successfully！(97/1)
# clip successfully！(1/1)
# clip mask successfully！(1/1)
# clip mask successfully！(2/1)
# clip mask successfully！(3/1)
# clip mask successfully！(4/1)
# clip mask successfully！(5/1)
# clip mask successfully！(6/1)
# clip mask successfully！(7/1)
# clip mask successfully！(8/1)
# clip mask successfully！(9/1)
# clip mask successfully！(10/1)
# clip mask successfully！(11/1)
# clip mask successfully！(12/1)
# clip mask successfully！(13/1)
# clip mask successfully！(14/1)
# clip mask successfully！(15/1)
# clip mask successfully！(16/1)
# clip mask successfully！(17/1)
# clip mask successfully！(18/1)
# clip mask successfully！(19/1)
# clip mask successfully！(20/1)
# clip mask successfully！(21/1)
# clip mask successfully！(22/1)
# clip mask successfully！(23/1)
# clip mask successfully！(24/1)
# clip mask successfully！(25/1)
# clip mask successfully！(26/1)
# clip mask successfully！(27/1)
# clip mask successfully！(28/1)
# clip mask successfully！(29/1)
# clip mask successfully！(30/1)
# clip mask successfully！(31/1)
# clip mask successfully！(32/1)
# clip mask successfully！(33/1)
# clip mask successfully！(34/1)
# clip mask successfully！(35/1)
# clip mask successfully！(36/1)
# clip mask successfully！(37/1)
# clip mask successfully！(38/1)
# clip mask successfully！(39/1)
# clip mask successfully！(40/1)
# clip mask successfully！(41/1)
# clip mask successfully！(42/1)
# clip mask successfully！(43/1)
# clip mask successfully！(44/1)
# clip mask successfully！(45/1)
# clip mask successfully！(46/1)
# clip mask successfully！(47/1)
# clip mask successfully！(48/1)
# clip mask successfully！(49/1)
# clip mask successfully！(50/1)
# clip mask successfully！(51/1)
# clip mask successfully！(52/1)
# clip mask successfully！(53/1)
# clip mask successfully！(54/1)
# clip mask successfully！(55/1)
# clip mask successfully！(56/1)
# clip mask successfully！(57/1)
# clip mask successfully！(58/1)
# clip mask successfully！(59/1)
# clip mask successfully！(60/1)
# clip mask successfully！(61/1)
# clip mask successfully！(62/1)
# clip mask successfully！(63/1)
# clip mask successfully！(64/1)
# clip mask successfully！(65/1)
# clip mask successfully！(66/1)
# clip mask successfully！(67/1)
# clip mask successfully！(68/1)
# clip mask successfully！(69/1)
# clip mask successfully！(70/1)
# clip mask successfully！(71/1)
# clip mask successfully！(72/1)
# clip mask successfully！(73/1)
# clip mask successfully！(74/1)
# clip mask successfully！(75/1)
# clip mask successfully！(76/1)
# clip mask successfully！(77/1)
# clip mask successfully！(78/1)
# clip mask successfully！(79/1)
# clip mask successfully！(80/1)
# clip mask successfully！(81/1)
# clip mask successfully！(82/1)
# clip mask successfully！(83/1)
# clip mask successfully！(84/1)
# clip mask successfully！(85/1)
# clip mask successfully！(86/1)
# clip mask successfully！(87/1)
# clip mask successfully！(88/1)
# clip mask successfully！(89/1)
# clip mask successfully！(90/1)
# clip mask successfully！(91/1)
# clip mask successfully！(92/1)
# clip mask successfully！(93/1)
# clip mask successfully！(94/1)
# clip mask successfully！(95/1)
# clip mask successfully！(96/1)
# clip mask successfully！(97/1)
# clip mask successfully！(98/1)
# clip mask successfully！(99/1)
# clip mask successfully！(100/1)
# clip mask successfully！(101/1)
# clip mask successfully！(102/1)
# clip mask successfully！(103/1)
# clip mask successfully！(104/1)
# clip mask successfully！(105/1)
# clip mask successfully！(106/1)
# clip mask successfully！(107/1)
# clip mask successfully！(108/1)
# clip mask successfully！(109/1)
# clip mask successfully！(110/1)
# clip mask successfully！(111/1)
# clip mask successfully！(112/1)
# clip mask successfully！(113/1)
# clip mask successfully！(114/1)
# clip mask successfully！(115/1)
# clip mask successfully！(116/1)
# clip mask successfully！(117/1)
# clip mask successfully！(118/1)
# clip mask successfully！(119/1)
# clip mask successfully！(120/1)
# clip mask successfully！(121/1)
# clip mask successfully！(122/1)
# clip mask successfully！(123/1)
# clip mask successfully！(124/1)
# clip mask successfully！(125/1)
# clip mask successfully！(126/1)
# clip mask successfully！(127/1)
# clip mask successfully！(128/1)
# clip mask successfully！(129/1)
# clip mask successfully！(130/1)
# clip mask successfully！(131/1)
# clip mask successfully！(132/1)
# clip mask successfully！(133/1)
# clip mask successfully！(134/1)
# clip mask successfully！(135/1)
# clip mask successfully！(136/1)
# clip mask successfully！(137/1)
# clip mask successfully！(138/1)
# clip mask successfully！(139/1)
# clip mask successfully！(140/1)
# clip mask successfully！(141/1)
# clip mask successfully！(142/1)
# clip mask successfully！(143/1)
# clip mask successfully！(144/1)
# clip mask successfully！(145/1)
# clip mask successfully！(146/1)
# clip mask successfully！(147/1)
# clip mask successfully！(148/1)
# clip mask successfully！(149/1)
# clip mask successfully！(150/1)
# clip mask successfully！(151/1)
# clip mask successfully！(152/1)
# clip mask successfully！(153/1)
# clip mask successfully！(154/1)
# clip mask successfully！(155/1)
# clip mask successfully！(156/1)
# clip mask successfully！(157/1)
# clip mask successfully！(158/1)
# clip mask successfully！(159/1)
# clip mask successfully！(160/1)
# clip mask successfully！(161/1)
# clip mask successfully！(162/1)
# clip mask successfully！(163/1)
# clip mask successfully！(164/1)
# clip mask successfully！(165/1)
# clip mask successfully！(166/1)
# clip mask successfully！(167/1)
# clip mask successfully！(168/1)
# clip mask successfully！(169/1)
# clip mask successfully！(170/1)
# clip mask successfully！(171/1)
# clip mask successfully！(172/1)
# clip mask successfully！(173/1)
# clip mask successfully！(174/1)
# clip mask successfully！(175/1)
# clip mask successfully！(176/1)
# clip mask successfully！(177/1)
# clip mask successfully！(178/1)
# clip mask successfully！(179/1)
# clip mask successfully！(180/1)
# clip mask successfully！(181/1)
# clip mask successfully！(182/1)
# clip mask successfully！(183/1)
# clip mask successfully！(184/1)
# clip mask successfully！(185/1)
# clip mask successfully！(186/1)
# clip mask successfully！(187/1)
# clip mask successfully！(188/1)
# clip mask successfully！(189/1)
# clip mask successfully！(190/1)
# clip mask successfully！(191/1)
# clip mask successfully！(192/1)
# clip mask successfully！(193/1)
# clip mask successfully！(194/1)
# clip mask successfully！(195/1)
# clip mask successfully！(196/1)
# clip mask successfully！(197/1)
# clip mask successfully！(198/1)
# clip mask successfully！(199/1)
# clip mask successfully！(200/1)
# clip mask successfully！(201/1)
# clip mask successfully！(202/1)
# clip successfully！(1/1)
# clip mask successfully！(1/1)
# clip mask successfully！(2/1)
# clip mask successfully！(3/1)
# clip mask successfully！(4/1)
# clip mask successfully！(5/1)
# clip mask successfully！(6/1)
# clip mask successfully！(7/1)
# clip mask successfully！(8/1)
# clip mask successfully！(9/1)
# clip mask successfully！(10/1)
# clip mask successfully！(11/1)
# clip mask successfully！(12/1)
# clip mask successfully！(13/1)
# clip mask successfully！(14/1)
# clip mask successfully！(15/1)
# clip mask successfully！(16/1)
# clip mask successfully！(17/1)
# clip mask successfully！(18/1)
# clip mask successfully！(19/1)
# clip mask successfully！(20/1)
# clip mask successfully！(21/1)
# clip mask successfully！(22/1)
# clip mask successfully！(23/1)
# clip mask successfully！(24/1)
# clip mask successfully！(25/1)
# clip mask successfully！(26/1)
# clip mask successfully！(27/1)
# clip mask successfully！(28/1)
# clip mask successfully！(29/1)
# clip mask successfully！(30/1)
# clip mask successfully！(31/1)
# clip mask successfully！(32/1)
# clip mask successfully！(33/1)
# clip mask successfully！(34/1)
# clip mask successfully！(35/1)
# clip mask successfully！(36/1)
# clip mask successfully！(37/1)
# clip mask successfully！(38/1)
# clip mask successfully！(39/1)
# clip mask successfully！(40/1)
# clip mask successfully！(41/1)
# clip mask successfully！(42/1)
# clip mask successfully！(43/1)
# clip mask successfully！(44/1)
# clip mask successfully！(45/1)
# clip mask successfully！(46/1)
# clip mask successfully！(47/1)
# clip mask successfully！(48/1)
# clip mask successfully！(49/1)
# clip mask successfully！(50/1)
# clip mask successfully！(51/1)
# clip mask successfully！(52/1)
# clip mask successfully！(53/1)
# clip mask successfully！(54/1)
# clip mask successfully！(55/1)
# clip mask successfully！(56/1)
# clip mask successfully！(57/1)
# clip mask successfully！(58/1)
# clip mask successfully！(59/1)
# clip mask successfully！(60/1)
# clip mask successfully！(61/1)
# clip mask successfully！(62/1)
# clip mask successfully！(63/1)
# clip mask successfully！(64/1)
# clip mask successfully！(65/1)
# clip mask successfully！(66/1)
# clip mask successfully！(67/1)
# clip mask successfully！(68/1)
# clip mask successfully！(69/1)
# clip mask successfully！(70/1)
# clip mask successfully！(71/1)
# clip mask successfully！(72/1)
# clip mask successfully！(73/1)
# clip mask successfully！(74/1)
# clip mask successfully！(75/1)
# clip mask successfully！(76/1)
# clip mask successfully！(77/1)
# clip mask successfully！(78/1)
# clip mask successfully！(79/1)
# clip mask successfully！(80/1)
# clip mask successfully！(81/1)
# clip mask successfully！(82/1)
# clip mask successfully！(83/1)
# clip mask successfully！(84/1)
# clip mask successfully！(85/1)
# clip mask successfully！(86/1)
# clip mask successfully！(87/1)
# clip mask successfully！(88/1)
# clip mask successfully！(89/1)
# clip mask successfully！(90/1)
# clip mask successfully！(91/1)
# clip mask successfully！(92/1)
# clip mask successfully！(93/1)
# clip mask successfully！(94/1)
# clip mask successfully！(95/1)
# clip mask successfully！(96/1)
# clip mask successfully！(97/1)
# clip mask successfully！(98/1)
# clip mask successfully！(99/1)
# clip mask successfully！(100/1)
# clip mask successfully！(101/1)
# clip mask successfully！(102/1)
# clip mask successfully！(103/1)
# clip mask successfully！(104/1)
# clip mask successfully！(105/1)
# clip mask successfully！(106/1)
# clip mask successfully！(107/1)
# clip mask successfully！(108/1)
# clip mask successfully！(109/1)
# clip mask successfully！(110/1)
# clip mask successfully！(111/1)
# clip mask successfully！(112/1)
# clip successfully！(1/1)
# clip mask successfully！(1/1)
# clip mask successfully！(2/1)
# clip mask successfully！(3/1)
# clip mask successfully！(4/1)
# clip mask successfully！(5/1)
# clip mask successfully！(6/1)
# clip mask successfully！(7/1)
# clip mask successfully！(8/1)
# clip mask successfully！(9/1)
# clip mask successfully！(10/1)
# clip mask successfully！(11/1)
# clip successfully！(1/1)
# clip mask successfully！(1/1)
# clip mask successfully！(2/1)
# clip mask successfully！(3/1)
# clip mask successfully！(4/1)
# clip mask successfully！(5/1)
# clip mask successfully！(6/1)
# clip mask successfully！(7/1)
# clip mask successfully！(8/1)
# clip mask successfully！(9/1)
# clip mask successfully！(10/1)
# clip mask successfully！(11/1)
# clip mask successfully！(12/1)
# clip mask successfully！(13/1)
# clip mask successfully！(14/1)
# clip mask successfully！(15/1)
# clip mask successfully！(16/1)
# clip mask successfully！(17/1)
# clip mask successfully！(18/1)
# clip mask successfully！(19/1)
# clip mask successfully！(20/1)
# clip mask successfully！(21/1)
# clip mask successfully！(22/1)
# clip mask successfully！(23/1)
# clip mask successfully！(24/1)
# clip mask successfully！(25/1)
# clip mask successfully！(26/1)
# clip mask successfully！(27/1)
# clip mask successfully！(28/1)
# clip mask successfully！(29/1)
# clip mask successfully！(30/1)
# clip mask successfully！(31/1)
# clip mask successfully！(32/1)
# clip mask successfully！(33/1)
# clip mask successfully！(34/1)
# clip mask successfully！(35/1)
# clip mask successfully！(36/1)
# clip mask successfully！(37/1)
# clip mask successfully！(38/1)
# clip mask successfully！(39/1)
# clip mask successfully！(40/1)
# clip mask successfully！(41/1)
# clip mask successfully！(42/1)
# clip mask successfully！(43/1)
# clip mask successfully！(44/1)
# clip mask successfully！(45/1)
# clip mask successfully！(46/1)
# clip mask successfully！(47/1)
# clip mask successfully！(48/1)
# clip mask successfully！(49/1)
# clip mask successfully！(50/1)
# clip mask successfully！(51/1)
# clip mask successfully！(52/1)
# clip mask successfully！(53/1)
# clip mask successfully！(54/1)
# clip mask successfully！(55/1)
# clip mask successfully！(56/1)
# clip mask successfully！(57/1)
# clip mask successfully！(58/1)
# clip mask successfully！(59/1)
# clip mask successfully！(60/1)
# clip mask successfully！(61/1)
# clip mask successfully！(62/1)
# clip mask successfully！(63/1)
# clip mask successfully！(64/1)
# clip mask successfully！(65/1)
# clip mask successfully！(66/1)
# clip mask successfully！(67/1)
# clip mask successfully！(68/1)
# clip mask successfully！(69/1)
# clip mask successfully！(70/1)
# clip mask successfully！(71/1)
# clip mask successfully！(72/1)
# clip mask successfully！(73/1)
# clip mask successfully！(74/1)
# clip mask successfully！(75/1)
# clip mask successfully！(76/1)
# clip mask successfully！(77/1)
# clip mask successfully！(78/1)
# clip mask successfully！(79/1)
# clip mask successfully！(80/1)
# clip mask successfully！(81/1)
# clip mask successfully！(82/1)
# clip mask successfully！(83/1)
# clip mask successfully！(84/1)
# clip mask successfully！(85/1)
# clip mask successfully！(86/1)
# clip mask successfully！(87/1)
# clip mask successfully！(88/1)
# clip mask successfully！(89/1)
# clip mask successfully！(90/1)
# clip mask successfully！(91/1)
# clip mask successfully！(92/1)
# clip mask successfully！(93/1)
# clip mask successfully！(94/1)
# clip mask successfully！(95/1)
# clip mask successfully！(96/1)
# clip mask successfully！(97/1)
# clip mask successfully！(98/1)
# clip mask successfully！(99/1)
# clip mask successfully！(100/1)
# clip mask successfully！(101/1)
# clip mask successfully！(102/1)
# clip mask successfully！(103/1)
# clip mask successfully！(104/1)
# clip successfully！(1/1)
# clip mask successfully！(1/1)
# clip mask successfully！(2/1)
# clip mask successfully！(3/1)
# clip mask successfully！(4/1)
# clip mask successfully！(5/1)
# clip mask successfully！(6/1)
# clip mask successfully！(7/1)
# clip mask successfully！(8/1)
# clip mask successfully！(9/1)
# clip mask successfully！(10/1)
# clip mask successfully！(11/1)
# clip mask successfully！(12/1)
# clip mask successfully！(13/1)
# clip mask successfully！(14/1)
# clip mask successfully！(15/1)
# clip mask successfully！(16/1)
# clip mask successfully！(17/1)
# clip mask successfully！(18/1)
# clip mask successfully！(19/1)
# clip mask successfully！(20/1)
# clip mask successfully！(21/1)
# clip mask successfully！(22/1)
# clip mask successfully！(23/1)
# clip mask successfully！(24/1)
# clip mask successfully！(25/1)
# clip mask successfully！(26/1)
# clip mask successfully！(27/1)
# clip mask successfully！(28/1)
# clip mask successfully！(29/1)
# clip mask successfully！(30/1)
# clip mask successfully！(31/1)
# clip mask successfully！(32/1)
# clip mask successfully！(33/1)
# clip mask successfully！(34/1)
# clip mask successfully！(35/1)
# clip mask successfully！(36/1)
# clip mask successfully！(37/1)
# clip mask successfully！(38/1)
# clip mask successfully！(39/1)
# clip mask successfully！(40/1)
# clip mask successfully！(41/1)
# clip mask successfully！(42/1)
# clip mask successfully！(43/1)
# clip mask successfully！(44/1)
# clip mask successfully！(45/1)
# clip mask successfully！(46/1)
# clip mask successfully！(47/1)
# clip mask successfully！(48/1)
# clip mask successfully！(49/1)
# clip mask successfully！(50/1)
# clip mask successfully！(51/1)
# clip mask successfully！(52/1)
# clip mask successfully！(53/1)
# clip mask successfully！(54/1)
# clip mask successfully！(55/1)
# clip mask successfully！(56/1)
# clip mask successfully！(57/1)
# clip mask successfully！(58/1)
# clip mask successfully！(59/1)
# clip mask successfully！(60/1)
# clip mask successfully！(61/1)
# clip mask successfully！(62/1)
# clip mask successfully！(63/1)
# clip mask successfully！(64/1)
# clip mask successfully！(65/1)
# clip mask successfully！(66/1)
# clip mask successfully！(67/1)
# clip mask successfully！(68/1)
# clip mask successfully！(69/1)
# clip mask successfully！(70/1)
# clip mask successfully！(71/1)
# clip mask successfully！(72/1)
# clip mask successfully！(73/1)
# clip mask successfully！(74/1)
# clip mask successfully！(75/1)
# clip mask successfully！(76/1)
# clip mask successfully！(77/1)
# clip mask successfully！(78/1)
# clip mask successfully！(79/1)
# clip mask successfully！(80/1)
# clip mask successfully！(81/1)
# clip mask successfully！(82/1)
# clip mask successfully！(83/1)
# clip mask successfully！(84/1)
# clip mask successfully！(85/1)
# clip mask successfully！(86/1)
# clip mask successfully！(87/1)
# clip mask successfully！(88/1)
# clip mask successfully！(89/1)
# clip mask successfully！(90/1)
# clip mask successfully！(91/1)
# clip mask successfully！(92/1)
# clip mask successfully！(93/1)
# clip mask successfully！(94/1)
# clip mask successfully！(95/1)
# clip mask successfully！(96/1)
# clip mask successfully！(97/1)
# clip mask successfully！(98/1)
# clip mask successfully！(99/1)
# clip mask successfully！(100/1)
# clip mask successfully！(101/1)
# clip mask successfully！(102/1)
# clip mask successfully！(103/1)
# clip mask successfully！(104/1)
# clip mask successfully！(105/1)
# clip mask successfully！(106/1)
# clip mask successfully！(107/1)
# clip mask successfully！(108/1)
# clip mask successfully！(109/1)
# clip mask successfully！(110/1)
# clip mask successfully！(111/1)
# clip mask successfully！(112/1)
# clip mask successfully！(113/1)
# clip mask successfully！(114/1)
# clip mask successfully！(115/1)
# clip mask successfully！(116/1)
# clip mask successfully！(117/1)
# clip mask successfully！(118/1)
# clip mask successfully！(119/1)
# clip mask successfully！(120/1)
# clip mask successfully！(121/1)
# clip mask successfully！(122/1)
# clip mask successfully！(123/1)
# clip mask successfully！(124/1)
# clip mask successfully！(125/1)
# clip mask successfully！(126/1)
# clip mask successfully！(127/1)
# clip mask successfully！(128/1)
# clip mask successfully！(129/1)
# clip mask successfully！(130/1)
# clip mask successfully！(131/1)
# clip mask successfully！(132/1)
# clip mask successfully！(133/1)
# clip mask successfully！(134/1)
# clip mask successfully！(135/1)
# clip mask successfully！(136/1)
# clip successfully！(1/1)
# clip mask successfully！(1/1)
# clip mask successfully！(2/1)
# clip mask successfully！(3/1)
# clip mask successfully！(4/1)
# clip mask successfully！(5/1)
# clip mask successfully！(6/1)
# clip mask successfully！(7/1)
# clip mask successfully！(8/1)
# clip mask successfully！(9/1)
# clip mask successfully！(10/1)
# clip mask successfully！(11/1)
# clip mask successfully！(12/1)
# clip mask successfully！(13/1)
# clip mask successfully！(14/1)
# clip mask successfully！(15/1)
# clip mask successfully！(16/1)
# clip mask successfully！(17/1)
# clip mask successfully！(18/1)
# clip mask successfully！(19/1)
# clip mask successfully！(20/1)
# clip mask successfully！(21/1)
# clip mask successfully！(22/1)
# clip mask successfully！(23/1)
# clip mask successfully！(24/1)
# clip mask successfully！(25/1)
# clip mask successfully！(26/1)
# clip mask successfully！(27/1)
# clip mask successfully！(28/1)
# clip mask successfully！(29/1)
# clip mask successfully！(30/1)
# clip mask successfully！(31/1)
# clip mask successfully！(32/1)
# clip mask successfully！(33/1)
# clip mask successfully！(34/1)
# clip mask successfully！(35/1)
# clip mask successfully！(36/1)
# clip mask successfully！(37/1)
# clip mask successfully！(38/1)
# clip mask successfully！(39/1)
# clip mask successfully！(40/1)
# clip mask successfully！(41/1)
# clip mask successfully！(42/1)
# clip mask successfully！(43/1)
# clip mask successfully！(44/1)
# clip mask successfully！(45/1)
# clip mask successfully！(46/1)
# clip mask successfully！(47/1)
# clip mask successfully！(48/1)
# clip mask successfully！(49/1)
# clip mask successfully！(50/1)
# clip mask successfully！(51/1)
# clip mask successfully！(52/1)
# clip mask successfully！(53/1)
# clip mask successfully！(54/1)
# clip mask successfully！(55/1)
# clip mask successfully！(56/1)
# ...
# /home/shamil/AILab/new_data/dataset/test/annotations/8_uchastok_39.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/8_uchastok_14.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/8_uchastok_103.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/8_uchastok_44.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/8_uchastok_70.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/8_uchastok_8.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/8_uchastok_107.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/8_uchastok_81.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/8_uchastok_30.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/8_uchastok_54.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/8_uchastok_27.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/8_uchastok_83.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/8_uchastok_76.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/8_uchastok_0.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/8_uchastok_106.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/8_uchastok_17.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/8_uchastok_55.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/8_uchastok_98.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/8_uchastok_48.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/8_uchastok_41.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/8_uchastok_105.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/8_uchastok_87.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/8_uchastok_65.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/8_uchastok_40.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/8_uchastok_92.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/8_uchastok_99.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/8_uchastok_29.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/8_uchastok_45.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/8_uchastok_43.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/8_uchastok_74.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/8_uchastok_6.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/8_uchastok_59.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/8_uchastok_46.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/8_uchastok_58.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/8_uchastok_102.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/8_uchastok_72.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/8_uchastok_64.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/8_uchastok_21.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/8_uchastok_79.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/8_uchastok_10.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/19_uchastok_41.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/19_uchastok_38.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/19_uchastok_40.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/19_uchastok_63.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/19_uchastok_15.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/19_uchastok_35.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/19_uchastok_67.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/19_uchastok_34.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/19_uchastok_9.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/19_uchastok_1.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/19_uchastok_30.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/19_uchastok_33.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/19_uchastok_64.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/19_uchastok_23.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/19_uchastok_24.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/19_uchastok_52.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/19_uchastok_26.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/19_uchastok_66.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/19_uchastok_48.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/19_uchastok_65.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/19_uchastok_44.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/19_uchastok_19.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/19_uchastok_28.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/19_uchastok_61.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/19_uchastok_6.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/19_uchastok_37.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/19_uchastok_21.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/19_uchastok_11.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/19_uchastok_58.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/19_uchastok_42.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/19_uchastok_7.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/19_uchastok_20.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/19_uchastok_59.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/19_uchastok_51.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/19_uchastok_18.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/19_uchastok_47.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/19_uchastok_22.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/19_uchastok_46.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/19_uchastok_43.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/19_uchastok_0.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/19_uchastok_54.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/19_uchastok_8.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/19_uchastok_39.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/19_uchastok_45.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/19_uchastok_53.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/19_uchastok_50.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/19_uchastok_55.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/19_uchastok_16.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/19_uchastok_2.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/19_uchastok_29.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/19_uchastok_14.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/19_uchastok_10.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/19_uchastok_49.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/19_uchastok_57.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/19_uchastok_4.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/19_uchastok_62.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/19_uchastok_12.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/19_uchastok_60.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/19_uchastok_32.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/19_uchastok_31.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/19_uchastok_17.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/19_uchastok_3.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/19_uchastok_13.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/19_uchastok_36.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/19_uchastok_56.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/19_uchastok_5.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/19_uchastok_25.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/19_uchastok_27.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_3.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_20.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_35.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_8.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_13.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_67.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_57.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_25.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_64.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_66.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_7.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_34.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_21.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_4.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_96.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_44.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_65.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_51.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_11.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_5.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_85.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_19.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_50.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_75.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_26.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_89.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_1.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_54.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_9.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_73.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_78.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_90.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_77.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_80.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_70.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_87.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_17.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_91.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_0.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_94.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_55.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_81.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_41.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_74.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_30.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_15.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_24.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_48.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_38.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_32.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_61.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_71.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_43.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_33.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_22.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_6.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_53.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_46.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_83.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_14.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_59.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_68.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_31.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_18.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_92.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_58.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_88.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_40.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_60.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_93.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_45.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_63.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_39.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_12.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_56.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_16.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_37.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_95.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_76.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_86.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_72.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_47.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_79.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_69.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_29.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_84.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_28.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_42.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_23.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_62.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_27.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_49.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_52.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_10.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_36.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_2.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/11_uchastok_82.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/6_uchastok_7.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/6_uchastok_12.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/6_uchastok_11.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/6_uchastok_2.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/6_uchastok_17.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/6_uchastok_5.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/6_uchastok_6.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/6_uchastok_14.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/6_uchastok_1.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/6_uchastok_4.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/6_uchastok_3.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/6_uchastok_0.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/6_uchastok_9.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/6_uchastok_15.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/6_uchastok_13.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/6_uchastok_10.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/6_uchastok_8.tif
# /home/shamil/AILab/new_data/dataset/test/annotations/6_uchastok_16.tif
